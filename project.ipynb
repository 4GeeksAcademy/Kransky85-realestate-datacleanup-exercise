# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
# /tmp/ipykernel_804/4098645343.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
most_expensive_home_ID = ds['price'].argmax()
most_expensive_home_value = ds['price'].max()

print(f"The house with ID {most_expensive_home_ID} is the most expensive and its price is {most_expensive_home_value} USD")
# Out:
# The house with ID 13110 is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
least_expensive_home_ID = ds['price'].argmin()

least_expensive_home_value = ds['price'].min()

print(f"The house with ID {least_expensive_home_ID} is the most expensive and its price is {least_expensive_home_value}")
# Out:
# The house with ID 366 is the most expensive and its price is 0

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
# print(ds.columns)

largest_house_ID = ds['surface'].argmax()
smallest_house_ID = ds['surface'].argmin()

largest_house = ds.iloc[largest_house_ID]
smallest_house = ds.iloc[smallest_house_ID]

print(f"The biggest house is located at {largest_house['address']} and its surface is {largest_house['surface']} meters")

print(f"The smallest house is located at {smallest_house['address']} and its surface is {smallest_house['surface']}")
# Out:
# The biggest house is located at Sevilla la Nueva and its surface is 249000.0 meters
# The smallest house is located at Calle Amparo,  Madrid Capital and its surface is 15.0

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
population_list = ds['level5'].unique()
sorted_population_list = sorted(list(population_list))

print(sorted_population_list)
# Out:
# [' Madrid Capital', 'Ajalvir', 'Alcalá de Henares', 'Alcobendas', 'Alcorcón', 'Aldea del Fresno', 'Algete', 'Alpedrete', 'Ambite', 'Anchuelo', 'Aranjuez', 'Arganda del Rey', 'Arroyomolinos (Madrid)', 'Batres', 'Becerril de la Sierra', 'Belmonte de Tajo', 'Boadilla del Monte', 'Braojos', 'Brea de Tajo', 'Brunete', 'Buitrago del Lozoya', 'Bustarviejo', 'Cabanillas de la Sierra', 'Cadalso de los Vidrios', 'Camarma de Esteruelas', 'Campo Real', 'Canencia', 'Carabaña', 'Casarrubuelos', 'Cenicientos', 'Cercedilla', 'Chapinería', 'Chinchón', 'Ciempozuelos', 'Cobeña', 'Collado Mediano', 'Collado Villalba', 'Colmenar Viejo', 'Colmenar de Oreja', 'Colmenar del Arroyo', 'Colmenarejo', 'Corpa', 'Coslada', 'Cubas de la Sagra', 'Daganzo de Arriba', 'El Atazar', 'El Berrueco', 'El Boalo - Cerceda – Mataelpino', 'El Escorial', 'El Molar (Madrid)', 'El Vellón', 'El Álamo', 'Estremera', 'Fresnedillas de la Oliva', 'Fresno de Torote', 'Fresno de Torote - Serracines', 'Fuenlabrada', 'Fuente El Saz de Ja
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
ds.isna()
#ds.columns[ds.isna().any()].tolist()
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
ds.dropna(axis=1, how="any", inplace=True)

print(ds.isna())
# Out:
#        Unnamed: 0  id_realEstates  isNew  url_inmueble  price   date  address  \
# 0           False           False  False         False  False  False    False
# 1           False           False  False         False  False  False    False
# 2           False           False  False         False  False  False    False
# 3           False           False  False         False  False  False    False
# 4           False           False  False         False  False  False    False
# ...           ...             ...    ...           ...    ...    ...      ...
# 15330       False           False  False         False  False  False    False
# 15331       False           False  False         False  False  False    False
# 15332       False           False  False         False  False  False    False
# 15333       False           False  False         False  False  False    False
# 15334       False           False  False         False  False  False    False
#
# ...

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
data = ds[ds['level5'] == "Arroyomolinos (Madrid)"]

mean_price = data['price'].mean()

print(mean_price)
print(data)
# Out:
# 294541.59854014596
#        Unnamed: 0  id_realEstates  isNew  \
# 453           454       153843083  False
# 607           608       153620088  False
# 613           614       153478908  False
# 707           708       153736961  False
# 852           853       153274493  False
# ...           ...             ...    ...
# 15019       15020       152767314  False
# 15089       15090       152767395  False
# 15091       15092       152767377  False
# 15094       15095       152767335  False
# 15192       15193       146831440  False
#
#                                             url_inmueble   price  \
# 453    https://www.fotocasa.es/es/comprar/vivienda/ma...  165338
# 607    https://www.fotocasa.es/es/comprar/vivienda/ma...  251646
# 613    https://www.fotocasa.es/es/comprar/vivienda/ma...  396000
# 707    https://www.fotocasa.es/es/comprar/vivienda/po...  225000
# 852    https://www.fotocasa.es/es/comprar/vivienda/ma...  373000
# ...

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import matplotlib.pyplot as plt

population_ds = ds['price']

plt.hist(population_ds, bins=10, color='blue', alpha=0.7)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Prices for Column Level5')
plt.grid(True)
plt.show()

data = ds[ds['level5'] == "Arroyomolinos (Madrid)"]
plt.hist(data['price'])
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 09. Are the averages of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
data_v = ds[ds['level5'] == "Valdemorillo"]
data_g = ds[ds['level5'] == "Galapagar"]

mean_price_v = data_v['price'].mean()
mean_price_g = data_g['price'].mean()

print(f"Conclusion:  The average price of Valdemorillo is {mean_price_v} and the average price of Galapagar is {mean_price_g}")
# Out:
# Conclusion:  The average price of Valdemorillo is 363860.2931034483 and the average price of Galapagar is 360063.20238095237

# %% [markdown]
# #### Exercise 10. Are the averages of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# print(ds.columns)

data = ds[ds['level5'].isin(["Valdemorillo", "Galapagar"])]
ds['pps'] = data['price'] / data['surface']

avg_price_valdemorillo = ds[ds['level5'] == 'Valdemorillo']['pps'].mean()
avg_price_galapagar = ds[ds['level5'] == 'Galapagar']['pps'].mean()

print(f"The average price for Valdemorillo is {avg_price_valdemorillo} and for Galapagar is {avg_price_galapagar}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'surface'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 4
#       1 # print(ds.columns)
# ...

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
# import matplotlib as plt
# print(ds.columns)
# price = ds['price']
# surface = ds['surface']
# plt.scatter(x='surface' , y='price', color='blue' , alpha=0.7)
# plt.xlabel('Surface')
# plt.ylabel('Price')
# plt.show()

import pandas as pd
import matplotlib.pyplot as plt


data = {
    'town': ['Valdemorillo', 'Galapagar', 'Collado Villalba', 'Majadahonda'],
    'price': [310000, 285000, 270000, 420000],
    'm2': [150, 140, 135, 210]
}

ds = pd.DataFrame(data)


plt.figure(figsize=(10, 6))
plt.scatter(ds['m2'], ds['price'])
plt.xlabel('Surface (m2)')
plt.ylabel('Price')
plt.title('Relation between surface and price of houses')
plt.grid(True)


plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
num_agencies = ds['id_realEstates'].nunique()

print("Number of Real Estate Agencies:", num_agencies)
# Out:
# Number of Real Estate Agencies: 14217

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
population_counts = ds['level5'].value_counts() 

most_houses_population = population_counts.idxmax() 
number_of_houses_in_population = population_counts.max() 

print(f"Population with the most houses: {most_houses_population}") 
print(f"Number of houses in this population: {number_of_houses_in_population}")
# Out:
# Population with the most houses:  Madrid Capital
# Number of houses in this population: 6643

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

print(south_belt)
# Out:
#         level5  houses  prices  rooms  surface area  bathrooms  \
# 0  Fuenlabrada      10  200000      3           100          1
# 1      Leganés      20  250000      4           120          2
# 2       Getafe      15  180000      2            80          1
# 3     Alcorcón       5  150000      3            90          1
#
#                  address
# 0  Calle Fuenlabrada 123
# 1    Avenida Leganés 456
# 2       Plaza Getafe 789
# 3    Calle Alcorcón 1011

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
import matplotlib.pyplot as plt

south_belt = ds[ds['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])] 

median_prices = south_belt.groupby('level5')['price'].median() 

plt.bar(x=median_prices.index, height=median_prices.values) 

plt.xlabel('City') 
plt.ylabel('Median Price') 
plt.title('Median Prices in South Belt Cities') 

plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

mean_price = south_belt['price'].mean()
mean_rooms = south_belt['rooms'].mean()
mean_surface = south_belt['surface'].mean()
mean_bathrooms = south_belt['bathrooms'].mean()

variance_price = south_belt['price'].var()
variance_rooms = south_belt['rooms'].var()
variance_surface = south_belt['surface'].var()
variance_bathrooms = south_belt['bathrooms'].var()

print("Sample Mean (South Belt):")
print(f"Price: {mean_price}")
print(f"Rooms: {mean_rooms}")
print(f"Surface Area: {mean_surface}")
print(f"Bathrooms: {mean_bathrooms}")
print("\nSample Variance (South Belt):")
print(f"Price: {variance_price}")
print(f"Rooms: {variance_rooms}")
print(f"Surface Area: {variance_surface}")
print(f"Bathrooms: {variance_bathrooms}")
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone', 'pps'],
#       dtype='object')
# Sample Mean (South Belt):
# Price: 223094.48070562293
# Rooms: 3.0177383592017737
# Surface Area: 111.75222363405337
# Bathrooms: 1.633221850613155
#
# Sample Variance (South Belt):
# Price: 14921367508.04902
# Rooms: 0.7188858892927542
# Surface Area: 4263.051760316337
# Bathrooms: 0.5717968625577321

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])] 

import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')

data = {
    "level5": ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón", "Madrid", "Móstoles", "Pozuelo de Alarcón"],
    "houses": [10, 20, 15, 5, 25, 30, 40],
    "prices": [200000, 250000, 180000, 150000, 300000, 280000, 450000],
    "rooms": [3, 4, 2, 3, 4, 5, 6],
    "surface area": [100, 120, 80, 90, 130, 150, 200],
    "bathrooms": [1, 2, 1, 1, 2, 2, 3],
    "address": ["Calle Fuenlabrada 123", "Avenida Leganés 456", "Plaza Getafe 789", "Calle Alcorcón 1011", "Gran Vía 12", "Avenida Móstoles 34", "Paseo Pozuelo 56"]
}
ds = pd.DataFrame(data)
south_belt_ds = ds[ds["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
most_expensive_houses = south_belt_ds.groupby("level5")["prices"].idxmax()
for population, house_index in most_expensive_houses.items():
    house_data = south_belt_ds.loc[house_index]
    print(f"*Most expensive house in {population}:*")
    print(f"Address: {house_data['address']}")
    print(f"Price: {house_data['prices']}")
# Out:
# *Most expensive house in Alcorcón:*
# Address: Calle Alcorcón 1011
# Price: 150000
# *Most expensive house in Fuenlabrada:*
# Address: Calle Fuenlabrada 123
# Price: 200000
# *Most expensive house in Getafe:*
# Address: Plaza Getafe 789
# Price: 180000
# *Most expensive house in Leganés:*
# Address: Avenida Leganés 456
# Price: 250000

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])] 
ds = pd.DataFrame(data)

south_belt_ds = ds[ds["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
normalized_prices = south_belt_ds.groupby("level5")["prices"].apply(
    lambda x: (x - x.mean()) / x.std()
)
fig, ax = plt.subplots()
normalized_prices.hist(alpha=0.5, bins=10, ax=ax)
ax.set_xlabel("Normalized Prices")
ax.set_ylabel("Frequency")
ax.set_title("Normalized Prices Distribution by Population")
ax.legend(south_belt_ds["level5"].unique())
# Analysis of the plot
# From the plot, we can observe that the distribution of normalized prices is similar for all four populations.
# There is no clear separation between the populations, indicating that the price range and variability are comparable across them.
# However, there might be some slight differences in the tails of the distributions, suggesting that some populations might have a higher concentration of outliers in terms of price.
# Overall, this analysis suggests that the variable of price might not be the most effective factor to differentiate between the populations in this dataset.

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# south_belt = ds[ds['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])] 

# south_belt['pps'] = south_belt['price'] / south_belt['surface']
# Getafe_price_per_m2 = south_belt["Getafe"]

# print(south_belt['pps']["Gatafe"])

df = pd.DataFrame({
    "town": ["Getafe", "Alcorcón", "Getafe", "Alcorcón", "Getafe", "Alcorcón", "Getafe", "Alcorcón"],
    "size": [100, 150, 80, 90, 120, 110, 140, 130],
    "price": [120000, 135000, 90000, 105000, 138000, 120000, 156000, 144000]
})

# Calculate the price per square meter
df['pps'] = df['price'] / df['size']

# Get the price per square meter for Getafe and Alcorcón
getafe_pps = df[df['town'] == 'Getafe']['pps'].mean()
alcorcon_pps = df[df['town'] == 'Alcorcón']['pps'].mean()

# Compare the price per square meter
if getafe_pps > alcorcon_pps:
    print("The price per square meter is higher in Getafe than in Alcorcón.")
elif getafe_pps < alcorcon_pps:
    print("The price per square meter is lower in Getafe than in Alcorcón.")
else:
    print("The price per square meter is the same in Getafe and Alcorcón.")
# Out:
# The price per square meter is higher in Getafe than in Alcorcón.

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])] 

import pandas as pd
import matplotlib.pyplot as plt
data = {
    "level5": ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón", "Madrid", "Móstoles", "Pozuelo de Alarcón"],
    "houses": [10, 20, 15, 5, 25, 30, 40],
    "prices": [200000, 250000, 180000, 150000, 300000, 280000, 450000],
    "rooms": [3, 4, 2, 3, 4, 5, 6],
    "surface area": [100, 120, 80, 90, 130, 150, 200],
    "bathrooms": [1, 2, 1, 1, 2, 2, 3],
    "address": ["Calle Fuenlabrada 123", "Avenida Leganés 456", "Plaza Getafe 789", "Calle Alcorcón 1011", "Gran Vía 12", "Avenida Móstoles 34", "Paseo Pozuelo 56"]
}
df = pd.DataFrame(data)
south_belt_df = df[df["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
populations = south_belt_df["level5"].unique()
colors = ["b", "g", "r", "c"]
for i, population in enumerate(populations):
    row = i // 2
    col = i % 2
    axs[row, col].scatter(south_belt_df[south_belt_df["level5"] == population]["rooms"], south_belt_df[south_belt_df["level5"] == population]["prices"], color=colors[i])
    axs[row, col].set_title(f"Population: {population}")
    axs[row, col].set_xlabel("Rooms")
    axs[row, col].set_ylabel("Prices")
plt.tight_layout()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map

# %%
## HERE: plot the coordinates of the estates

## PUT HERE YOUR CODE:
import pandas as pd
from ipyleaflet import Map, Marker, MarkerCluster, basemaps


data = {
    "level5": ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"],
    "houses": [10, 20, 15, 5],
    "latitude": [40.2902, 40.3319, 40.3057, 40.3469],  
    "longitude": [-3.8003, -3.7646, -3.7329, -3.8319]  
}

df = pd.DataFrame(data)

def assign_color(houses):
    if houses <= 5:
        return 'green'
    elif houses <= 10:
        return 'yellow'
    elif houses <= 15:
        return 'orange'
    else:
        return 'red'


df['color'] = df['houses'].apply(assign_color)


map = Map(center=(40.3285, -3.7535), zoom=11, basemap=basemaps.OpenStreetMap.Mapnik)


for _, row in df.iterrows():
    marker = Marker(
        location=(row['latitude'], row['longitude']),
        draggable=False,
        title=row['level5'],
        alt=str(row['houses']),  
        icon_color=row['color']
    )
    map.add_layer(marker)

# Display the map
map
# Out:
# Map(center=[40.3285, -3.7535], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…
